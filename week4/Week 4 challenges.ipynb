# %%
subjects = []
for i in range(6):
    subject = input(f"Enter a subject {i+1}: ")
    topic = input(f'Enter the topic for {subject}')
    subjects.append((subject,topic))
print(subjects)
# Out:
# [('a', 'a'), ('a', ''), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a')]
# maths	differentiation
# history	WW2
# Geog	Migration
# Physics	Stars
# Chem	Bonds
# Bio	Plants

# %%
subs = [('maths', 'differentiation'), ('history', 'WW2'), ('Geog', 'Migration'), ('Physics', 'Stars'), ('Chem', 'Bonds'), ('Bio', 'Plants')]
for i in range(len(subs)):
    print(f'{subs[i][0]}\t{subs[i][1]}')
tofind = input("Enter a subject to find: ")
for i in range(len(subs)):
    if subs[i][0] ==tofind.lower():
        print("Found")
# Out:
# maths	differentiation
# history	WW2
# Geog	Migration
# Physics	Stars
# Chem	Bonds
# Bio	Plants
# Found

# %%
def trialCode():
    name = input("What is your name?")
    while len(name) ==0:
        name = input("What is your name?")
    while True:
                try:
                    length = float(input('Enter the length: '))
                    width = float(input('Enter the width:'))
                    height = float(input('Enter the height: '))
                    break
                except ValueError:
                        print('Don\'t be silly we need numbers only')

    print(f'The volume of the cube is {length*width*height} cubic units')

# %%
def scoreChallenge():
    '''Scorer validation challenge'''
    scores =[]
    while True:
        try:
             score = int(input('Enter a test score'))
             scores.append(score)
             response = input('Want to continue (y/n):')
             if response.lower() == "n":
                break 
        except ValueError:
             print('Score needs to be a whole number')
    return scores

# %%
scores = scoreChallenge()
for score in scores:
    print(score)
# Out:
# 65
# 65
# 65
# 67
